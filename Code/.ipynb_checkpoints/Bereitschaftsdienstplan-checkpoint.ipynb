# %%
import Analysis.dataPrep as data_prep
df, df_build_notes, summary_list = data_prep.sickness_table_df()
print('\n'.join(df_build_notes))
# Out:
# Daten erfolgreich in einen DataFrame umgewandelt
# Keine fehlenden Daten in der CSV-Datei
# Keine nicht-ganzzahligen Werte in den Spalten 'n_sick', 'calls', 'n_duty', 'n_sby', 'sby_need', 'dafted'
# Alle Daten zwischen Start- und Enddatum vorhanden
# Alle Spalten ausser 'date' in Integer umgewandelt
# Alle Daten in der 'date'-Spalte sind Datetime-Datentyp

# %%
for i in summary_list:
    print(i, '\n')
# Out:
# Dataframe Info:
#
#                       date       n_sick         calls       n_duty   n_sby  \
# count                 1152  1152.000000   1152.000000  1152.000000  1152.0
# mean   2017-10-28 12:00:00    68.808160   7919.531250  1820.572917    90.0
# min    2016-04-01 00:00:00    36.000000   4074.000000  1700.000000    90.0
# 25%    2017-01-13 18:00:00    58.000000   6978.000000  1800.000000    90.0
# 50%    2017-10-28 12:00:00    68.000000   7932.000000  1800.000000    90.0
# 75%    2018-08-12 06:00:00    78.000000   8827.500000  1900.000000    90.0
# max    2019-05-27 00:00:00   119.000000  11850.000000  1900.000000    90.0
# std                    NaN    14.293942   1290.063571    80.086953     0.0
#
#           sby_need       dafted
# count  1152.000000  1152.000000
# mean     34.718750    16.335938
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%      12.250000     0.000000
# max     555.000000   465.000000
# std      79.694251    53.394089
#
#         date  n_sick  calls  n_duty  n_sby  sby_need  dafted
# 0 2016-04-01      73   8154    1700     90         4       0
# 1 2016-04-02      64   8526    1700     90        70       0
# 2 2016-04-03      68   8088    1700     90         0       0
# 3 2016-04-04      71   7044    1700     90         0       0
# 4 2016-04-05      63   7236    1700     90         0       0
#
#            date  n_sick  calls  n_duty  n_sby  sby_need  dafted
# 1147 2019-05-23      86   8544    1900     90         0       0
# 1148 2019-05-24      81   8814    1900     90         0       0
# 1149 2019-05-25      76   9846    1900     90       146      56
# 1150 2019-05-26      83   9882    1900     90       160      70
# 1151 2019-05-27      77   8790    1900     90         0       0

# %%
data_prep.describe_data(df)
# Out:
# Werte in der n_sby-Spalte:[90]
# Werte in der n_duty-Spalte:[1700 1800 1900]

# %%
data_prep.overview_scatter(df)

# %%
df_2 = data_prep.new_columns(df) # Neue Spalten erstellen
df_2
# Out:
#            date  n_sick  calls  n_duty  n_sby  sby_need  dafted  demand  \
# 0    2016-04-01      73   8154    1700     90         4       0  1631.0
# 1    2016-04-02      64   8526    1700     90        70       0  1706.0
# 2    2016-04-03      68   8088    1700     90         0       0     NaN
# 3    2016-04-04      71   7044    1700     90         0       0     NaN
# 4    2016-04-05      63   7236    1700     90         0       0     NaN
# ...         ...     ...    ...     ...    ...       ...     ...     ...
# 1147 2019-05-23      86   8544    1900     90         0       0     NaN
# 1148 2019-05-24      81   8814    1900     90         0       0     NaN
# 1149 2019-05-25      76   9846    1900     90       146      56  1970.0
# 1150 2019-05-26      83   9882    1900     90       160      70  1977.0
# 1151 2019-05-27      77   8790    1900     90         0       0     NaN
#
#       n_sick_adj
# 0             82
# 1             72
# 2             76
# 3             79
# 4             70
# ...          ...
# 1147          86
# 1148          81
# 1149          76
# 1150          83
# 1151          77
#
# [1152 rows x 9 columns]

# %%
data_prep.demand_vs_calls(df_2)

# %%
reg, reg_score, df_demand_predict = data_prep.notrufe_demand_reg(df_2)
reg_score
# Out:
# 0.9999955382315575

# %% [markdown]
# Aus dem Streuungsdiagramm ist es deutlich klar, dass ein lineares Verhältnis zwischen der Anzahl an Notrufen und der Gesamtnachfrage nach Einsatzfahrenden gibt. Das bedeutet, dass die zwei Hauptfragen mit denen wir uns beschäftigen sollten, sind ob die Anzahl an Anrufen und Krankenstände vorhergesagt kann.

# %%
df_demand_predict, ax, reg, reg_score = data_prep.notruf_reg(df_demand_predict)
import matplotlib.pyplot as plt
plt.show()

# %%
reg_score
# Out:
# 0.148748112671504

# %%
data_prep.no_trend_scatter(df_demand_predict)

# %%
df_demand_predict = data_prep.new_columns(df_demand_predict)
df_demand_predict = data_prep.ney_featturtes(df_demand_predict)
df_demand_predict
# Out:
#            date  n_sick  calls  n_duty  n_sby  sby_need  dafted  demand  \
# 0    2016-04-01      73   8154    1700     90         4       0  1631.0
# 1    2016-04-02      64   8526    1700     90        70       0  1706.0
# 2    2016-04-03      68   8088    1700     90         0       0     NaN
# 3    2016-04-04      71   7044    1700     90         0       0     NaN
# 4    2016-04-05      63   7236    1700     90         0       0     NaN
# ...         ...     ...    ...     ...    ...       ...     ...     ...
# 1147 2019-05-23      86   8544    1900     90         0       0     NaN
# 1148 2019-05-24      81   8814    1900     90         0       0     NaN
# 1149 2019-05-25      76   9846    1900     90       146      56  1970.0
# 1150 2019-05-26      83   9882    1900     90       160      70  1977.0
# 1151 2019-05-27      77   8790    1900     90         0       0     NaN
#
#       n_sick_adj  demand_pred  calls_reg_pred  calls_reg_act_diff
# 0             82         1631            7059                1095
# 1             72         1706            7060                1466
# 2             76         1618            7062                1026
# 3             79         1409            7063                 -19
# 4             70         1448            7065                 171
# ...          ...          ...             ...                 ...
# 1147          86         1709            8774                -230
# 1148          81         1763            8776                  38
# 1149          76         1970            8777                1069
# 1150          83         1977            8779                1103
# 1151          77         1758            8780                  10
#
# [1152 rows x 12 columns]

# %%
# Random Forest um die wichtigsten Features zu finden
predictions, feat_gini_importance, results_df, models = data_prep.my_model_options(df_demand_predict)
print(feat_gini_importance.sort_values(ascending=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Random Forest um die wichtigsten Features zu finden
# ----> 2 predictions, feat_gini_importance, results_df, models = data_prep.my_model_options(df_demand_predict)
#       3 print(feat_gini_importance.sort_values(ascending=False))
#
# File c:\Users\maxst\Dropbox\Weiterbildung\IU\Mods\FsME\Prog\TDSP-BsdEf\Code\Analysis\dataPrep.py:552, in my_model_options(df)
#     549 def my_model_options(df):
#     550
#     551     # Merkmalsvariablen von Zielvariable trennen
# --> 552     X = df[['month', 'year', 'dayofmonth', 'weekday', 'weekofyear', 'dayofyear', 'season']]
#     553     y = df['calls_reg_act_diff']
#     554     X_train = X[:-47]
#
# File ~\Dropbox\Weiterbildung\IU\Mods\FsME\Prog\TDSP-BsdEf\BsdEf_venv\lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~\Dropbox\Weiterbildung\IU\Mods\FsME\Prog\TDSP-BsdEf\BsdEf_venv\lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~\Dropbox\Weiterbildung\IU\Mods\FsME\Prog\TDSP-BsdEf\BsdEf_venv\lib\site-packages\pandas\core\indexes\base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['month', 'year', 'dayofmonth', 'weekday', 'weekofyear', 'dayofyear',\n       'season'],\n      dtype='object')] are in the [columns]"

# %%
print(results_df)

# %%
predictions

# %%
data_prep.plot_train_test(predictions, df_demand_predict)

# %%
data_prep.plot_train_test(predictions, df_demand_predict)

# %% [markdown]
# ##### Datenerfassung und -verständnis

# %% [markdown]
# #### Processbeschreibung
#
# #### Beschreibung der relevanten Rollen
#
# #### Sammlung von Hilfsmitteln und Softwaretools

# %% [markdown]
# Archiv
#
# #### Data-Science-Lebenszyklus
# - Geschäftsverständnis
# - Modellierung
#     - Merkmalsgenerierung
#     - Training
#     - Evaluierung
# - Datenerfassung, und -verständnis
#     - Datenquelle
#
# - Bereitstellung
#     - Speicherung des Modells
#     - Webservice
#     - Anwendungen
